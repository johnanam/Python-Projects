# %%
#pip install chart_studio

# %%
import pandas as pd 
import numpy as np 
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.9.0

# %%
import cufflinks as cf

# %%
 from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns="A B C D".split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.707419 -0.982495 -0.042417 -1.613634
# 1 -0.078837 -0.670110  0.644614  1.516342
# 2  0.291425 -0.884380  0.821123 -2.393644
# 3  1.262735 -0.052678 -0.263313  0.707371
# 4 -1.114145 -0.629686 -0.626193 -0.821630

# %%
df2 = pd.DataFrame({"Category":['A','B','C'],'values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>                            <div id="a81f493d-5286-466f-a040-54c072e0f89e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#scatter plot 
df.iplot(kind='scatter',x = 'A',y='B',mode = 'markers',size = 10,color = 'blue')
# Out:
# <div>                            <div id="7c48dd9d-953b-4829-a5a9-67080b78fdd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind = 'bar',x='Category', y = 'values')
# Out:
# <div>                            <div id="f3e30908-4235-40b4-995a-d56c9a26942c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -0.044771  1.093030 -0.280300 -0.268436
# 1  -1.879899 -0.509006 -0.714159 -1.194650
# 2  -0.470946  0.995419 -1.156838 -0.422305
# 3   0.165093 -2.418058 -0.762793  0.698201
# 4  -0.437415 -1.266694 -0.355512  0.472410
# ..       ...       ...       ...       ...
# 95 -1.265633  0.332978 -0.383059 -0.153243
# 96  0.316777  0.036229 -0.124090  1.206408
# 97 -0.284731  0.735867 -0.277520  0.110603
# 98 -0.096631 -0.887609  0.292483  0.016635
# 99 -0.567120  1.777693 -0.147133 -1.190426
#
# [100 rows x 4 columns]

# %%
df.sum().iplot(kind = 'bar')
# Out:
# <div>                            <div id="1b85fe28-abb8-4d85-b2de-731d727ea1b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'box')
# Out:
# <div>                            <div id="1da9654e-fbb3-4654-abcf-a9ee9b714697" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# 3 D
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind = 'surface',size = 20)  # surface plot
# Out:
# <div>                            <div id="a09a1e07-c180-4d88-ac6c-e3aa773c0c0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind = 'surface')  # surface plot
# Out:
# <div>                            <div id="c8ff84b6-0545-46b1-a274-e52bd31e15a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind = 'surface',colorscale = 'rdylbu')  # surface plot
# Out:
# <div>                            <div id="e281b702-1cab-432b-85a7-50c5ff773e5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'hist')  # surface plot
# Out:
# <div>                            <div id="f73698ed-f398-4516-96f1-ab63f5c2e567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# spread 
df[['A','B']].iplot(kind = 'spread')
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="b4241942-725e-4672-bd2f-73230f822fe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# bubble plot 
df.iplot(kind = 'bubble',x= 'A',y = 'B', size = 'C',color = 'grey')
# Out:
# <div>                            <div id="3b286d34-9c24-45dc-a6a5-6c319288106e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# scatter matrix plot 

df.scatter_matrix()
# Out:
# <div>                            <div id="04f3cbc4-aa83-4179-8fb3-7d97637c7001" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# github.cufflinks for more information

# %%
df.iplot(kind = 'area')
# Out:
# <div>                            <div id="f4f740d9-6ac1-4fb3-a72d-8f8d2c67e628" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# ! jt -t [theme name] -T.
