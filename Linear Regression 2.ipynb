# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#pip install scikit-learn

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\Boston.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  year  month  day  high_temp_f  avg_temp_f  low_temp_f  \
# 0           1  2008      1    1           40          34          28
# 1           2  2008      1    2           33          22          10
# 2           3  2008      1    3           14          11           7
# 3           4  2008      1    4           32          20           8
# 4           5  2008      1    5           42          35          27
#
#    high_dew_point_f  avg_dew_point_f  low_dew_point_f  ...  \
# 0                37               31               22  ...
# 1                28               18               -3  ...
# 2                -3               -7               -9  ...
# 3                13                5               -8  ...
# 4                26               16               12  ...
#
#    low_sea_level_press_in  high_visibility_mi  avg_visibility_mi  \
# 0                   29.56                  10                  8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3749 entries, 0 to 3748
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               3749 non-null   int64
#  1   year                     3749 non-null   int64
#  2   month                    3749 non-null   int64
#  3   day                      3749 non-null   int64
#  4   high_temp_f              3749 non-null   int64
#  5   avg_temp_f               3749 non-null   int64
#  6   low_temp_f               3749 non-null   int64
#  7   high_dew_point_f         3749 non-null   int64
#  8   avg_dew_point_f          3749 non-null   int64
#  9   low_dew_point_f          3749 non-null   int64
#  10  high_humidity_percent    3749 non-null   int64
#  11  avg_humidity_percent     3749 non-null   int64
#  12  low_humidity_percent     3749 non-null   int64
#  13  high_sea_level_press_in  3749 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month', 'day', 'high_temp_f', 'avg_temp_f',
#        'low_temp_f', 'high_dew_point_f', 'avg_dew_point_f', 'low_dew_point_f',
#        'high_humidity_percent', 'avg_humidity_percent', 'low_humidity_percent',
#        'high_sea_level_press_in', 'avg_sea_level_press_in',
#        'low_sea_level_press_in', 'high_visibility_mi', 'avg_visibility_mi',
#        'low_visibility_mi', 'high_wind_mph', 'avg_wind_mph',
#        'high_wind_gust_mph', 'snowfall_in', 'precip_in', 'events'],
#       dtype='object')

# %%
#sns.pairplot(df)

# %%
sns.distplot(df['precip_in'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11064\1204612775.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['precip_in'])
# <Axes: xlabel='precip_in', ylabel='Density'>

# %%
plt.figure(figsize = (30,20))
sns.heatmap(df.corr(),annot = True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11064\1270671406.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month', 'day', 'high_temp_f', 'avg_temp_f',
#        'low_temp_f', 'high_dew_point_f', 'avg_dew_point_f', 'low_dew_point_f',
#        'high_humidity_percent', 'avg_humidity_percent', 'low_humidity_percent',
#        'high_sea_level_press_in', 'avg_sea_level_press_in',
#        'low_sea_level_press_in', 'high_visibility_mi', 'avg_visibility_mi',
#        'low_visibility_mi', 'high_wind_mph', 'avg_wind_mph',
#        'high_wind_gust_mph', 'snowfall_in', 'precip_in', 'events'],
#       dtype='object')

# %%
X = df[[ 'year', 'month', 'day', 'high_temp_f', 'avg_temp_f',
       'low_temp_f', 'high_dew_point_f', 'avg_dew_point_f', 'low_dew_point_f',
       'high_humidity_percent', 'avg_humidity_percent', 'low_humidity_percent',
       'high_sea_level_press_in', 'avg_sea_level_press_in',
       'low_sea_level_press_in', 'high_visibility_mi', 'avg_visibility_mi',
       'low_visibility_mi', 'high_wind_mph', 'avg_wind_mph',
       'high_wind_gust_mph', 'snowfall_in']]

# %%
y = df['precip_in']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.30, random_state= 100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -0.09920624545755628

# %%
lm.coef_
# Out:
# array([-4.14193617e-05,  2.62100669e-04,  3.57393295e-04,  1.43420718e-03,
#        -5.41779388e-03,  4.04246539e-03,  1.37990885e-03,  2.95312480e-03,
#        -9.75296365e-04,  1.37084118e-03, -9.29381147e-03,  7.87990189e-03,
#         5.27614704e-01, -5.56689238e-01,  3.57650600e-02,  3.52669188e-02,
#        -5.58680779e-02, -1.77413552e-03,  1.29360122e-02, -5.04019649e-03,
#        -2.05193123e-03,  3.04822215e-01])

# %%
X_train.columns
# Out:
# Index(['year', 'month', 'day', 'high_temp_f', 'avg_temp_f', 'low_temp_f',
#        'high_dew_point_f', 'avg_dew_point_f', 'low_dew_point_f',
#        'high_humidity_percent', 'avg_humidity_percent', 'low_humidity_percent',
#        'high_sea_level_press_in', 'avg_sea_level_press_in',
#        'low_sea_level_press_in', 'high_visibility_mi', 'avg_visibility_mi',
#        'low_visibility_mi', 'high_wind_mph', 'avg_wind_mph',
#        'high_wind_gust_mph', 'snowfall_in'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coef'])

# %%
cdf
# Out:
#                              Coef
# year                    -0.000041
# month                    0.000262
# day                      0.000357
# high_temp_f              0.001434
# avg_temp_f              -0.005418
# low_temp_f               0.004042
# high_dew_point_f         0.001380
# avg_dew_point_f          0.002953
# low_dew_point_f         -0.000975
# high_humidity_percent    0.001371
# avg_humidity_percent    -0.009294
# low_humidity_percent     0.007880
# high_sea_level_press_in  0.527615
# avg_sea_level_press_in  -0.556689
# low_sea_level_press_in   0.035765
# high_visibility_mi       0.035267
# avg_visibility_mi       -0.055868
# low_visibility_mi       -0.001774
# high_wind_mph            0.012936
# avg_wind_mph            -0.005040
# high_wind_gust_mph      -0.002052
# snowfall_in              0.304822

# %% [markdown]
# # predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([0.04210949, 0.09703891, 0.02280896, ..., 0.12563578, 0.01613658,
#        0.02599735])

# %%
y_train
# Out:
# 784     0.00
# 2944    0.00
# 2838    0.34
# 3474    0.00
# 1016    0.00
#         ...
# 1930    0.00
# 79      0.27
# 1859    0.00
# 2840    0.00
# 1544    0.00
# Name: precip_in, Length: 2624, dtype: float64

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 0.12752134403338475

# %%
metrics.mean_squared_error(y_test,predictions)
# Out:
# 0.05877079480405292

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 0.24242688548107225
